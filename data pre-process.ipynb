# %%
import os
import ants

# Specify input and output directories
input_dir = r"D:\Parkinson\data_nifti"  # Directory containing input NIfTI files
output_dir = r"D:\Parkinson\output_affine"  # Directory to save the output affine registered images

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# List all NIfTI files in the input directory
input_files = [file for file in os.listdir(input_dir) if file.endswith(".nii.gz")]

# Load fixed image (assuming it's the same for all registrations)
fixed_image_path = r"D:\Parkinson\ch2.nii"
fixed_image = ants.image_read(fixed_image_path)

# Iterate over each input file
for filename in input_files:
    # Construct the full path to the moving image
    moving_image_path = os.path.join(input_dir, filename)
    
    # Load the moving image
    moving_image = ants.image_read(moving_image_path)
    
    # Perform affine registration
    affine_transform = ants.registration(fixed=fixed_image, moving=moving_image, type_of_transform='Affine')
    affine_registered_image = ants.apply_transforms(fixed=fixed_image, moving=moving_image, transformlist=affine_transform['fwdtransforms'])
    
    # Save the affine registered image
    output_file_path = os.path.join(output_dir, f"affine_registered_{filename}")
    ants.image_write(affine_registered_image, output_file_path)
    
    print(f"Affine registered image saved to: {output_file_path}")
# Out:
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20220124075007_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20220217145452_5.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20220510070901_4.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20220809145341_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20220908085421_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20230713090638_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20230817081630_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_Anon_20230906085101_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_20141015161930_2.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20110408093305_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20110601092209_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20110812150845_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20111012090259_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20111012100248_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20111110142010_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20111116135016_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20111130093442_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20111130124916_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120125101860_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120131083745_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120209133520_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120419095048_4.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120613083803_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120614140659_10.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120625152058_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120711095017_4.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120713084233_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120725093807_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20120917095349_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121010095843_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121018141442_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121113110643_11.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121116100325_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121120120718_11.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121203141010_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20121206090025_10.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20130103095541_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20130110092513_10.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20130204133726_10.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20130321093240_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20130401103554_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20130415100441_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20151130092813_10.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20160309090437_9.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20170130090029_13.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20170222114117_7.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_GRAPPA_20180403142339_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_T1_SAG_20120322102047_10.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_w_GRAPPA_20140528142854_13.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_w_GRAPPA_20150209130921_14.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_MPRAGE_w_GRAPPA_20150928195452_13.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_MPRAGE_GRAPPA_20120911121643_3.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_MPRAGE_GRAPPA_20190619131437_6.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_MPRAGE_GRAPPA_20190619131437_7.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110426093906_8.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110513082240_2.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110520074818_5.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110615093610_2.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20120323091643_2.nii.gz
# Affine registered image saved to: D:\Parkinson\output_affine\affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20121026093847_2.nii.gz

# %%
import os
import nibabel as nib
import SimpleITK as sitk

# Define paths
input_dir = r"D:\Parkinson\output_affine"  # Directory containing affine registered images
output_dir = r"D:\Parkinson\affine_corrected"  # Directory to save corrected images

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# List all NIfTI files in the input directory
input_files = [file for file in os.listdir(input_dir) if file.endswith(".nii.gz")]

# Define the N4ITK bias field correction function
def apply_bias_field_correction(input_path, output_path):
    # Load the image using nibabel
    image = nib.load(input_path)
    
    # Convert nibabel image to SimpleITK image
    sitk_image = sitk.GetImageFromArray(image.get_fdata())
    
    # Apply N4ITK bias field correction
    corrector = sitk.N4BiasFieldCorrectionImageFilter()
    corrected_sitk_image = corrector.Execute(sitk_image)
    
    # Convert SimpleITK image back to nibabel image
    corrected_image = nib.Nifti1Image(sitk.GetArrayFromImage(corrected_sitk_image), image.affine)
    
    # Save the corrected image
    nib.save(corrected_image, output_path)

# Process each input file
for filename in input_files:
    # Construct input and output paths
    input_path = os.path.join(input_dir, filename)
    output_path = os.path.join(output_dir, f"corrected_{filename}")
    
    # Apply bias field correction
    apply_bias_field_correction(input_path, output_path)
    
    print(f"Corrected image saved to: {output_path}")
# Out:
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20220124075007_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20220217145452_5.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20220510070901_4.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20220809145341_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20220908085421_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20230713090638_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20230817081630_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_Anon_20230906085101_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_20141015161930_2.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20110408093305_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20110601092209_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20110812150845_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20111012090259_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20111012100248_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20111110142010_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20111116135016_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20111130093442_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20111130124916_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120125101860_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120131083745_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120209133520_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120419095048_4.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120613083803_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120614140659_10.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120625152058_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120711095017_4.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120713084233_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120725093807_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20120917095349_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121010095843_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121018141442_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121113110643_11.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121116100325_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121120120718_11.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121203141010_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20121206090025_10.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20130103095541_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20130110092513_10.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20130204133726_10.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20130321093240_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20130401103554_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20130415100441_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20151130092813_10.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20160309090437_9.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20170130090029_13.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20170222114117_7.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_GRAPPA_20180403142339_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_T1_SAG_20120322102047_10.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_w_GRAPPA_20140528142854_13.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_w_GRAPPA_20150209130921_14.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_MPRAGE_w_GRAPPA_20150928195452_13.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_MPRAGE_GRAPPA_20120911121643_3.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_MPRAGE_GRAPPA_20190619131437_6.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_MPRAGE_GRAPPA_20190619131437_7.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110426093906_8.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110513082240_2.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110520074818_5.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20110615093610_2.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20120323091643_2.nii.gz
# Corrected image saved to: D:\Parkinson\affine_corrected\corrected_affine_registered_merged_pd_SAG_T1_3D_MPRAGE_20121026093847_2.nii.gz
